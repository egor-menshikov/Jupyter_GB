# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', sep=',', encoding='Windows-1251')

# %%
df.sample(20)
# Out:
#       laptop_ID  Company                               Product  \
# 123         126       HP                           Probook 470
# 1170       1188       HP                                250 G5
# 379         385     Acer                              Aspire 7
# 1265       1283   Lenovo                    IdeaPad Y700-15ISK
# 1034       1048       HP                         EliteBook 850
# 1027       1041       HP                           ProBook 640
# 499         506   Lenovo                         ThinkPad L570
# 599         606     Dell                        Precision 3520
# 183         187  Toshiba                         Satellite Pro
# 1167       1185   Lenovo   320-15ISK (i3-6006U/4GB/1TB/GeForce
# 1261       1279     Asus                  ZenBook UX305CA-UBM1
# 619         626     Acer  CB5-132T-C9KK (N3160/4GB/32GB/Chrome
# 73           75      MSI                            GL72M 7RDX
# 1049       1063     Asus                     Chromebook C202SA
# 846         856       HP                       Chromebook X360
# 178         182   Lenovo          V310-15IKB (i5-7200U/8GB/1TB
# 162         166     Dell                         Inspiron 3576
# 877         888   Xiaomi                           Mi Notebook
# 1061       1075     Asus                     Rog G752VL-GC088D
# 749         758       HP                              Zbook 17
#
#                 TypeName  Inches                 ScreenResolution  \
# 123             Notebook    17.3                Full HD 1920x1080
# 1170            Notebook    15.6                Full HD 1920x1080
# 379             Notebook    15.6                Full HD 1920x1080
# 1265            Notebook    15.6      IPS Panel Full HD 1920x1080
# 1034            Notebook    15.6                Full HD 1920x1080
# 1027            Notebook    14.0                         1366x768
# 499             Notebook    15.6      IPS Panel Full HD 1920x1080
# 599          Workstation    15.6  Full HD / Touchscreen 1920x1080
# 183             Notebook    15.6                         1366x768
# 1167            Notebook    15.6                Full HD 1920x1080
# 1261           Ultrabook    13.3      IPS Panel Full HD 1920x1080
# 619   2 in 1 Convertible    11.6   IPS Panel Touchscreen 1366x768
# 73                Gaming    17.3                Full HD 1920x1080
# 1049             Netbook    11.6                         1366x768
# 846   2 in 1 Convertible    11.6             Touchscreen 1366x768
# 178             Notebook    15.6                Full HD 1920x1080
# 162             Notebook    15.6                Full HD 1920x1080
# 877            Ultrabook    13.3      IPS Panel Full HD 1920x1080
# 1061              Gaming    17.3      IPS Panel Full HD 1920x1080
# 749          Workstation    17.3      IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 123             Intel Core i7 8550U 1.8GHz  16GB             512GB SSD
# 1170            Intel Core i7 6500U 2.5GHz   8GB             256GB SSD
# 379            Intel Core i7 7700HQ 2.8GHz   8GB               1TB HDD
# 1265           Intel Core i7 6700HQ 2.6GHz   8GB               1TB HDD
# 1034            Intel Core i7 6500U 2.5GHz   8GB             256GB SSD
# 1027            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 499             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 599            Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 183             Intel Core i5 7200U 2.5GHz   8GB             128GB SSD
# 1167              Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 1261              Intel Core M 6Y30 0.9GHz   8GB             512GB SSD
# 619   Intel Celeron Quad Core N3160 1.6GHz   4GB    32GB Flash Storage
# 73             Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 1049  Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 846   Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 178             Intel Core i5 7200U 2.5GHz   8GB  128GB SSD +  1TB HDD
# 162             Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 877             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 1061           Intel Core i7 6700HQ 2.6GHz  16GB               1TB HDD
# 749          Intel Xeon E3-1535M v5 2.9GHz  16GB             256GB SSD
#
#                           Gpu       OpSys  Weight  Price_euros
# 123     Nvidia GeForce 930MX   Windows 10   2.5kg      1271.00
# 1170    Intel HD Graphics 520  Windows 10  1.96kg       679.00
# 379   Nvidia GeForce GTX 1050       Linux   2.4kg       846.00
# 1265  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1034    Intel HD Graphics 520  Windows 10  1.84kg      1228.99
# 1027    Intel HD Graphics 620  Windows 10  1.95kg      1060.00
# 499     Intel HD Graphics 620  Windows 10   2.3kg       911.00
# 599        Nvidia Quadro M620  Windows 10  2.06kg      1763.00
# 183     Intel HD Graphics 620  Windows 10   2.0kg       793.00
# 1167    Nvidia GeForce 920MX   Windows 10   2.2kg       468.00
# 1261    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 619     Intel HD Graphics 400   Chrome OS  1.25kg       379.00
# 73    Nvidia GeForce GTX 1050  Windows 10   2.7kg      1095.00
# 1049    Intel HD Graphics 400   Chrome OS   1.2kg       287.90
# 846     Intel HD Graphics 500   Chrome OS   1.4kg       615.00
# 178            AMD R17M-M1-70  Windows 10  1.90kg       813.00
# 162            AMD Radeon 520  Windows 10  2.13kg       728.00
# 877      Nvidia GeForce 940MX  Windows 10  1.28kg       935.00
# 1061  Nvidia GeForce GTX 965M       No OS     4kg       998.00
# 749      Nvidia Quadro M2000M   Windows 7     3kg      4389.00

# %%
df['Company'].value_counts()

# %%
df['Price_euros'].describe()

# %%
df[df['Price_euros'] == df['Price_euros'].max()]

# %%
df.sort_values('Price_euros', ascending=False).iloc[0]

# %%
df[df['Inches'] == df['Inches'].min()][['Company','TypeName','Inches','Price_euros']]

# %%
df[(df['Company'] == 'HP')].sort_values('Price_euros', ascending=False).iloc[0]

# %%
df[(df['Company'] == 'HP')]['Price_euros'].max()

# %%
df_working = df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')].shape[0]

# %%
df_all_ultras = df[df['TypeName'] == 'Ultrabook'].shape[0]

# %%
df_working / df_all_ultras * 100

# %%
df[((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] <= 500)]

# %%
df[(df['Ram'].isin(['8GB', '16GB'])) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] <= 500)]

# %%
df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & ~(df['Inches'] == 15.6)]

# %%
df_7700=df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()

# %%
df_7600=df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()

# %%
df_7700 > df_7600
# Out:
# False

# %% [markdown]
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype('float')
df['Weight'].min()
# Out:
# 0.69
